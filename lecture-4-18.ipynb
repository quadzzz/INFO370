# %% [markdown]
# ### 2024-04-18 CLT

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Pr = {0:0.5, 1:0.5}
X = set([0, 1])
s = 0
for x in X:
	s += Pr[x]*x
s
# Out:
# 0.5

# %%
np.random.binomial(2, 0.5, size = 10)
# Out:
# array([1, 2, 0, 1, 2, 1, 1, 1, 1, 0])

# %%
h = np.random.binomial(2, 0.5, size = 10)
np.mean(h)
# Out:
# 1.2

# %%
np.random.binomial(1, 0.5, size = 10)
# Out:
# array([1, 0, 1, 1, 1, 0, 0, 0, 1, 1])

# %%
x = np.random.binomial(1, 0.5, size = 10)
np.var(x)
# Out:
# 0.24

# %%
np.random.exponential(5, size = 10)
# Out:
# array([ 7.10744994,  5.47379753,  2.89412776,  3.19257541,  3.81633109,
#         0.40153794,  2.20269224,  8.17183707, 22.00677068,  7.96232008])

# %%
x = np.random.exponential(5, size = 1000)
_ = plt.hist(x, bins=30, edgecolor = "k")

# %%
x = np.random.exponential(5, size = 2)
np.mean(x)
# Out:
# 2.530830241656143

# %%
R = 1000
S = 2
avgs = []
for i in range(R):
	x = np.random.exponential(5, size = S)
	a = np.mean(x)
	avgs.append(a)

# %%
R = 1000
S = 2
avgs = []
for i in range(R):
	x = np.random.exponential(5, size = S)
	a = np.mean(x)
	avgs.append(a)

_ = plt.hist(avgs, bins=30, edgecolor = "k")

# %%
R = 1000
S = 2
avgs = []
for i in range(R):
	x = np.random.exponential(5, size = S)
	a = np.mean(x)
	avgs.append(a)

_ = plt.hist(avgs, bins=30, edgecolor = "k")
np.mean(avgs), np.var(avgs)
# Out:
# (4.907696908622227, 11.376122125250673)
